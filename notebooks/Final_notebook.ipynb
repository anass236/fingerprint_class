# %%
import os

os.add_dll_directory("C:/Program Files/NVIDIA GPU Computing Toolkit/CUDA/v11.0/bin")
os.add_dll_directory("C:/tools/cuda/bin")
# Out:
# <AddedDllDirectory('C:/tools/cuda/bin')>

# %%
# from utils.conf import ROOT_DIR
ROOT_DIR = "C:/Users/anass/my_ds/fingerprint_class"
import os
import cv2
import numpy as np
import random
from sklearn.model_selection import train_test_split
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras import layers, losses
import matplotlib.pyplot as plt
from tensorflow.keras.preprocessing.image import load_img, img_to_array

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Conv2D, MaxPooling2D, Flatten, BatchNormalization
import pydot

# %% [markdown]
# # Modèle de classification par genre

# %%
def extract_label(img_path, train = True):
    filename, _ = os.path.splitext(os.path.basename(img_path))
    subject_id, etc = filename.split('__')
    if train:
        gender, lr, finger, _ = etc.split('_')[:4]
    gender = 0 if gender=='M' else 1
    return gender

def loading_data(path,train, img_size):
    print("loading data from: ",path)
    data = []
    for img in os.listdir(path):
        img_array = cv2.imread(os.path.join(path, img), cv2.IMREAD_GRAYSCALE)
        img_resize = cv2.resize(img_array, (img_size, img_size))
        label = extract_label(os.path.join(path, img),train)
        data.append([label, img_resize])
    return data

def results(model, epoch, batch_size):
    r = model.fit(x_train, y_train, batch_size=batch_size, epochs=epoch, validation_data=(x_test, y_test), verbose=1)
    acc = model.evaluate(x_test, y_test)
    print("test set loss: ", acc[0])
    print("test set accuracy: ", acc[1]*100)
    epoch_range = range(1, epoch+1)
    plt.plot(epoch_range, r.history['accuracy'])
    plt.plot(epoch_range, r.history['val_accuracy'])
    plt.title('Classification Accuracy')
    plt.ylabel('Accuracy')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Val'], loc='lower right')
    plt.show()
    
    # Plot training & validation loss values
    plt.plot(epoch_range,r.history['loss'])
    plt.plot(epoch_range, r.history['val_loss'])
    plt.title('Model loss')
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Val'], loc='lower right')
    plt.show()

src_data = os.path.join(ROOT_DIR,"SOCOFing")
easy_data = loading_data(os.path.join(src_data, os.path.join("Altered","Altered-Easy")), True, 28)
medium_data = loading_data(os.path.join(src_data, os.path.join("Altered","Altered-Medium")), True, 28)
hard_data = loading_data(os.path.join(src_data, os.path.join("Altered","Altered-Hard")), True, 28)
data = np.concatenate([easy_data, medium_data, hard_data], axis=0)
import random

random.shuffle(data)

img, labels = [], []
for label, feature in data:
    labels.append(label)
    img.append(feature)
img = np.array(img).reshape(-1, 28, 28, 1)
labels = tf.keras.utils.to_categorical(labels)
x_train, x_test, y_train, y_test = train_test_split(img, labels, test_size=0.2, random_state=0)

print("x_train dimensions: ", x_train.shape)
print("x_test dimensions: ", x_test.shape)
print("y_train dimensions: ", y_train.shape)
print("y_test dimensions: ", y_test.shape)

x_train, x_val, y_train, y_val = train_test_split(x_train, y_train, test_size=0.05, random_state=0)

datagen = ImageDataGenerator(
            rotation_range=15,
            width_shift_range=0.1,
            height_shift_range=0.1,
            horizontal_flip=True)

def normalize(data):
    data = data.astype("float32")
    data = data/255
    return data

print("x_train dimensions: ", x_train.shape)
print("x_val dimensions: ", x_val.shape)
print("y_train dimensions: ", y_train.shape)
print("y_val dimensions: ", y_val.shape)


mirrored_strategy = tf.distribute.MirroredStrategy(devices=["/gpu:0"],cross_device_ops=tf.distribute.HierarchicalCopyAllReduce())

tf.keras.backend.clear_session()
weight_decay = 1e-4
with mirrored_strategy.scope():
    model_f = Sequential([
            Conv2D(32, (3, 3), activation = 'relu', padding = 'same',kernel_regularizer = tf.keras.regularizers.l2(weight_decay), input_shape = (28, 28, 1)),
            BatchNormalization(),
            Conv2D(32, (3, 3), activation = 'relu', kernel_regularizer =tf.keras.regularizers.l2(weight_decay), padding = 'same'),
            BatchNormalization(),
            MaxPooling2D((2, 2)),
            Dropout(0.2),
            Conv2D(64, (3, 3), activation = 'relu', kernel_regularizer = tf.keras.regularizers.l2(weight_decay), padding = 'same'),
            BatchNormalization(),
            Conv2D(64, (3, 3), activation = 'relu', kernel_regularizer =
            tf.keras.regularizers.l2(weight_decay), padding = 'same'),
            BatchNormalization(),
            MaxPooling2D((2, 2)),
            Dropout(0.3),
            Conv2D(128, (3, 3), activation = 'relu', kernel_regularizer =
            tf.keras.regularizers.l2(weight_decay), padding = 'same'),
            BatchNormalization(),
            Conv2D(128, (3, 3), activation = 'relu', kernel_regularizer =
            tf.keras.regularizers.l2(weight_decay), padding = 'same'),
            BatchNormalization(),
            MaxPooling2D((2, 2)),
            Dropout(0.3),
            Flatten(),
            Dense(128, activation = 'relu'),
            Dense(2, activation = 'softmax')
    ])
    model_f.summary()
    opt = tf.keras.optimizers.Adam(learning_rate=0.0001)
    model_f.compile(optimizer=opt, loss='binary_crossentropy', metrics=['accuracy'])
    results(model_f, 220, 128)

# test in Real data

real_data = loading_data(os.path.join(src_data, os.path.join("Real")), True, 28)
img, labels = [], []
for label, feature in real_data:
    labels.append(label)
    img.append(feature)
img = np.array(img).reshape(-1, 28, 28, 1)

# confusion matrix
from sklearn.metrics import classification_report, confusion_matrix
Y_pred = model_f.predict(img)
y_pred = np.argmax(Y_pred, axis=1)
print('Confusion Matrix')
print(confusion_matrix(labels, y_pred))
print('Classification Report')
target_names = ['Male', 'Female']
print(classification_report(labels, y_pred, target_names=target_names))
# Out:
# loading data from:  C:/Users/anass/my_ds/fingerprint_class\SOCOFing\Altered\Altered-Easy
# loading data from:  C:/Users/anass/my_ds/fingerprint_class\SOCOFing\Altered\Altered-Medium
# loading data from:  C:/Users/anass/my_ds/fingerprint_class\SOCOFing\Altered\Altered-Hard
# <__array_function__ internals>:5: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# x_train dimensions:  (39416, 28, 28, 1)
# x_test dimensions:  (9854, 28, 28, 1)
# y_train dimensions:  (39416, 2)
# y_test dimensions:  (9854, 2)
# x_train dimensions:  (37445, 28, 28, 1)
# x_val dimensions:  (1971, 28, 28, 1)
# y_train dimensions:  (37445, 2)
# y_val dimensions:  (1971, 2)
# WARNING:tensorflow:Collective ops is not configured at program startup. Some performance features may not be enabled.
# INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0',)
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 28, 28, 32)        320
# _________________________________________________________________
# batch_normalization (BatchNo (None, 28, 28, 32)        128
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 28, 28, 32)        9248
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 28, 28, 32)        128
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 14, 14, 32)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 14, 14, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 14, 14, 64)        18496
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 14, 14, 64)        256
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 14, 14, 64)        36928
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 14, 14, 64)        256
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 7, 7, 64)          0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 7, 7, 64)          0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 7, 7, 128)         73856
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 7, 7, 128)         512
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 7, 7, 128)         147584
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 7, 7, 128)         512
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 3, 3, 128)         0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 3, 3, 128)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 1152)              0
# _________________________________________________________________
# dense (Dense)                (None, 128)               147584
# _________________________________________________________________
# dense_1 (Dense)              (None, 2)                 258
# =================================================================
# Total params: 436,066
# Trainable params: 435,170
# Non-trainable params: 896
# _________________________________________________________________
# Epoch 1/220
# 293/293 [==============================] - 11s 24ms/step - loss: 0.5892 - accuracy: 0.7781 - val_loss: 0.5428 - val_accuracy: 0.7910
# Epoch 2/220
# 293/293 [==============================] - 6s 20ms/step - loss: 0.5136 - accuracy: 0.7921 - val_loss: 0.5268 - val_accuracy: 0.7883
# Epoch 3/220
# 293/293 [==============================] - 6s 20ms/step - loss: 0.4965 - accuracy: 0.7955 - val_loss: 0.5060 - val_accuracy: 0.7957
# Epoch 4/220
# 293/293 [==============================] - 6s 20ms/step - loss: 0.4852 - accuracy: 0.8032 - val_loss: 0.4959 - val_accuracy: 0.7994
# Epoch 5/220
# 293/293 [==============================] - 6s 20ms/step - loss: 0.4734 - accuracy: 0.8075 - val_loss: 0.4806 - val_accuracy: 0.8008
# Epoch 6/220
# 293/293 [==============================] - 6s 20ms/step - loss: 0.4635 - accuracy: 0.8102 - val_loss: 0.4584 - val_accuracy: 0.8165
# Epoch 7/220
# 293/293 [==============================] - 6s 20ms/step - loss: 0.4526 - accuracy: 0.8155 - val_loss: 0.4591 - val_accuracy: 0.8056
# Epoch 8/220
# 293/293 [==============================] - 6s 21ms/step - loss: 0.4394 - accuracy: 0.8242 - val_loss: 0.4157 - val_accuracy: 0.8404
# Epoch 9/220
# 293/293 [==============================] - 6s 21ms/step - loss: 0.4242 - accuracy: 0.8314 - val_loss: 0.4064 - val_accuracy: 0.8426
# Epoch 10/220
# 293/293 [==============================] - 6s 20ms/step - loss: 0.4065 - accuracy: 0.8388 - val_loss: 0.3888 - val_accuracy: 0.8533
# Epoch 11/220
# 293/293 [==============================] - 6s 21ms/step - loss: 0.3883 - accuracy: 0.8488 - val_loss: 0.3762 - val_accuracy: 0.8510
# Epoch 12/220
# 293/293 [==============================] - 6s 21ms/step - loss: 0.3754 - accuracy: 0.8539 - val_loss: 0.3145 - val_accuracy: 0.8906
# Epoch 13/220
# 293/293 [==============================] - 6s 21ms/step - loss: 0.3524 - accuracy: 0.8662 - val_loss: 0.3097 - val_accuracy: 0.8942
# Epoch 14/220
# 293/293 [==============================] - 6s 21ms/step - loss: 0.3323 - accuracy: 0.8758 - val_loss: 0.2688 - val_accuracy: 0.9154
# Epoch 15/220
# 293/293 [==============================] - 6s 21ms/step - loss: 0.3139 - accuracy: 0.8854 - val_loss: 0.2387 - val_accuracy: 0.9242
# Epoch 16/220
# 293/293 [==============================] - 6s 21ms/step - loss: 0.2989 - accuracy: 0.8900 - val_loss: 0.2370 - val_accuracy: 0.9293
# Epoch 17/220
# 293/293 [==============================] - 6s 21ms/step - loss: 0.2815 - accuracy: 0.8985 - val_loss: 0.2176 - val_accuracy: 0.9332
# Epoch 18/220
# 293/293 [==============================] - 6s 21ms/step - loss: 0.2672 - accuracy: 0.9066 - val_loss: 0.1960 - val_accuracy: 0.9451
# Epoch 19/220
# 293/293 [==============================] - 6s 21ms/step - loss: 0.2518 - accuracy: 0.9130 - val_loss: 0.1793 - val_accuracy: 0.9482
# Epoch 20/220
# 293/293 [==============================] - 6s 21ms/step - loss: 0.
220
# 293/293 [==============================] - 6s 20ms/step - loss: 0.0394 - accuracy: 0.9962 - val_loss: 0.0568 - val_accuracy: 0.9953
# Epoch 212/220
# 293/293 [==============================] - 6s 21ms/step - loss: 0.0390 - accuracy: 0.9966 - val_loss: 0.0575 - val_accuracy: 0.9950
# Epoch 213/220
# 293/293 [==============================] - 6s 20ms/step - loss: 0.0394 - accuracy: 0.9967 - val_loss: 0.0592 - val_accuracy: 0.9947
# Epoch 214/220
# 293/293 [==============================] - 6s 21ms/step - loss: 0.0382 - accuracy: 0.9967 - val_loss: 0.0531 - val_accuracy: 0.9959
# Epoch 215/220
# 293/293 [==============================] - 6s 20ms/step - loss: 0.0384 - accuracy: 0.9970 - val_loss: 0.0608 - val_accuracy: 0.9950
# Epoch 216/220
# 293/293 [==============================] - 6s 20ms/step - loss: 0.0391 - accuracy: 0.9963 - val_loss: 0.0583 - val_accuracy: 0.9952
# Epoch 217/220
# 293/293 [==============================] - 6s 20ms/step - loss: 0.0393 - accuracy: 0.9966 - val_loss: 0.0573 - val_accuracy: 0.9946
# Epoch 218/220
# 293/293 [==============================] - 6s 21ms/step - loss: 0.0384 - accuracy: 0.9964 - val_loss: 0.0540 - val_accuracy: 0.9953
# Epoch 219/220
# 293/293 [==============================] - 6s 21ms/step - loss: 0.0388 - accuracy: 0.9966 - val_loss: 0.0613 - val_accuracy: 0.9946
# Epoch 220/220
# 293/293 [==============================] - 6s 21ms/step - loss: 0.0386 - accuracy: 0.9967 - val_loss: 0.0596 - val_accuracy: 0.9955
# 308/308 [==============================] - 2s 6ms/step - loss: 0.0596 - accuracy: 0.9955
# test set loss:  0.05960329622030258
# test set accuracy:  99.55348372459412
# loading data from:  C:/Users/anass/my_ds/fingerprint_class\SOCOFing\Real
# Confusion Matrix
# [[4767    3]
#  [  19 1211]]
# Classification Report
#               precision    recall  f1-score   support
#
#         Male       1.00      1.00      1.00      4770
#       Female       1.00      0.98      0.99      1230
#
#     accuracy                           1.00      6000
#    macro avg       1.00      0.99      0.99      6000
# weighted avg       1.00      1.00      1.00      6000

# %%
tf.keras.utils.plot_model(model_f)

# %%
def extract_data(path, img_size):
    for img in os.listdir(path):
        ext = (img.split('_')[-1]).split('.')[0]
        img_array = cv2.imread(os.path.join(path, img), cv2.IMREAD_GRAYSCALE)
        img_resize = cv2.resize(img_array, (img_size, img_size))
        label = extract_label(os.path.join(path, img))
        if ext == 'CR':
            data_cr.append([label,img_resize])
        if ext == 'Zcut':
            data_zcut.append([label,img_resize])
        if ext == 'Obl':
            data_obl.append([label,img_resize])
    return data_cr, data_zcut, data_obl


data_cr, data_zcut, data_obl = [], [], []
src_data = os.path.join(ROOT_DIR,"SOCOFing")
data_cr, data_zcut, data_obl = extract_data(os.path.join(src_data, os.path.join("Altered","Altered-Easy")), img_size=96)
def loading_data(path, img_size):
    print("loading data from: ",path)
    data = []
    for img in os.listdir(path):
        img_array = cv2.imread(os.path.join(path, img), cv2.IMREAD_GRAYSCALE)
        img_resize = cv2.resize(img_array, (img_size, img_size))
        data.append(img_resize)
    return data
img, labels = [], []
for label, feature in data_cr:
    labels.append(label)
    img.append(feature)
data_cr = img

# %%
data_real = loading_data(os.path.join(src_data, "Real"), img_size=96)

data_real = data_real[:len(data_cr)]

x_cr_train, x_cr_test = train_test_split(data_cr, test_size=0.3, shuffle=True, random_state=42)
x_real_train, x_real_test = train_test_split(data_real, test_size=0.3, shuffle=True, random_state=42)

x_cr_train = np.array(x_cr_train).astype('float32') / 255.
x_cr_test = np.array(x_cr_test).astype('float32') / 255.
x_cr_train = tf.expand_dims(x_cr_train, axis=-1)
x_cr_test = tf.expand_dims(x_cr_test, axis=-1)

x_real_train = np.array(x_real_train).astype('float32') / 255.
x_real_test = np.array(x_real_test).astype('float32') / 255.
x_real_train = tf.expand_dims(x_real_train, axis=-1)
x_real_test = tf.expand_dims(x_real_test, axis=-1)

print ("data cr train", x_cr_train.shape)
print ("data cr test", x_cr_test.shape)
print("data real train", x_real_train.shape)
print("data real test", x_real_test.shape)
# Out:
# loading data from:  C:/Users/anass/my_ds/fingerprint_class\SOCOFing\Real
# data cr train (4178, 96, 96, 1)
# data cr test (1791, 96, 96, 1)
# data real train (4178, 96, 96, 1)
# data real test (1791, 96, 96, 1)

# %%
class Autoencoder(Model):
    def __init__(self, latent_dim):
        super(Autoencoder, self).__init__()
        self.encoder = tf.keras.Sequential([
          layers.Input(shape=(96, 96, 1)),
          layers.Conv2D(16, (3, 3), activation='relu', padding='same', strides=2),
          layers.Conv2D(8, (3, 3), activation='relu', padding='same', strides=2)])

        self.decoder = tf.keras.Sequential([
          layers.Conv2DTranspose(8, kernel_size=3, strides=2, activation='relu', padding='same'),
          layers.Conv2DTranspose(16, kernel_size=3, strides=2, activation='relu', padding='same'),
          layers.Conv2D(1, kernel_size=(3, 3), activation='sigmoid', padding='same')])

    def call(self, x):
        encoded = self.encoder(x)
        decoded = self.decoder(encoded)
        return decoded

mirrored_strategy = tf.distribute.MirroredStrategy(devices=["/gpu:0"],cross_device_ops=tf.distribute.HierarchicalCopyAllReduce())

tf.keras.backend.clear_session()
with mirrored_strategy.scope():
    autoencoder = Autoencoder(2)
    autoencoder.compile(optimizer='adam', loss=losses.MeanSquaredError())
    autoencoder.fit(x_cr_train, x_real_train,
                epochs=80,
                batch_size=128,
                shuffle=True,
                validation_data=(x_cr_test, x_real_test))
# Out:
# WARNING:tensorflow:Collective ops is not configured at program startup. Some performance features may not be enabled.
# INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0',)
# WARNING:tensorflow:Please add `keras.layers.InputLayer` instead of `keras.Input` to Sequential model. `keras.Input` is intended to be used by Functional model.
# Epoch 1/80
# 33/33 [==============================] - 5s 81ms/step - loss: 0.1479 - val_loss: 0.1352
# Epoch 2/80
# 33/33 [==============================] - 1s 42ms/step - loss: 0.1249 - val_loss: 0.1183
# Epoch 3/80
# 33/33 [==============================] - 1s 41ms/step - loss: 0.1171 - val_loss: 0.1148
# Epoch 4/80
# 33/33 [==============================] - 1s 41ms/step - loss: 0.1133 - val_loss: 0.1105
# Epoch 5/80
# 33/33 [==============================] - 1s 42ms/step - loss: 0.1087 - val_loss: 0.1059
# Epoch 6/80
# 33/33 [==============================] - 1s 40ms/step - loss: 0.1043 - val_loss: 0.1021
# Epoch 7/80
# 33/33 [==============================] - 1s 40ms/step - loss: 0.1004 - val_loss: 0.0982
# Epoch 8/80
# 33/33 [==============================] - 1s 40ms/step - loss: 0.0969 - val_loss: 0.0950
# Epoch 9/80
# 33/33 [==============================] - 1s 40ms/step - loss: 0.0945 - val_loss: 0.0943
# Epoch 10/80
# 33/33 [==============================] - 1s 40ms/step - loss: 0.0929 - val_loss: 0.0919
# Epoch 11/80
# 33/33 [==============================] - 1s 40ms/step - loss: 0.0920 - val_loss: 0.0912
# Epoch 12/80
# 33/33 [==============================] - 1s 40ms/step - loss: 0.0915 - val_loss: 0.0911
# Epoch 13/80
# 33/33 [==============================] - 1s 40ms/step - loss: 0.0910 - val_loss: 0.0906
# Epoch 14/80
# 33/33 [==============================] - 1s 40ms/step - loss: 0.0907 - val_loss: 0.0904
# Epoch 15/80
# 33/33 [==============================] - 1s 40ms/step - loss: 0.0904 - val_loss: 0.0898
# Epoch 16/80
# 33/33 [==============================] - 1s 40ms/step - loss: 0.0904 - val_loss: 0.0896
# Epoch 17/80
# 33/33 [==============================] - 1s 40ms/step - loss: 0.0900 - val_loss: 0.0894
# Epoch 18/80
# 33/33 [==============================] - 1s 40ms/step - loss: 0.0898 - val_loss: 0.0895
# Epoch 19/80
# 33/33 [==============================] - 1s 40ms/step - loss: 0.0897 - val_loss: 0.0891
# Epoch 20/80
# 33/33 [==============================] - 1s 40ms/step - loss: 0.0898 - val_loss: 0.0890
# Epoch 21/80
# 33/33 [==============================] - 1s 40ms/step - loss: 0.0899 - val_loss: 0.0890
# Epoch 22/80
# 33/33 [==============================] - 1s 40ms/step - loss: 0.0891 - val_loss: 0.0888
# Epoch 23/80
# 33/33 [==============================] - 1s 40ms/step - loss: 0.0891 - val_loss: 0.0888
# Epoch 24/80
# 33/33 [==============================] - 1s 40ms/step - loss: 0.0889 - val_loss: 0.0887
# Epoch 25/80
# 33/33 [==============================] - 1s 40ms/step - loss: 0.0889 - val_loss: 0.0885
# Epoch 26/80
# 33/33 [==============================] - 1s 40ms/step - loss: 0.0888 - val_loss: 0.0887
# Epoch 27/80
# 33/33 [==============================] - 1s 40ms/step - loss: 0.0890 - val_loss: 0.0885
# Epoch 28/80
# 33/33 [==============================] - 1s 40ms/step - loss: 0.0887 - val_loss: 0.0884
# Epoch 29/80
# 33/33 [==============================] - 1s 40ms/step - loss: 0.0886 - val_loss: 0.0881
# Epoch 30/80
# 33/33 [==============================] - 1s 40ms/step - loss: 0.0887 - val_loss: 0.0890
# Epoch 31/80
# 33/33 [==============================] - 1s 40ms/step - loss: 0.0885 - val_loss: 0.0881
# Epoch 32/80
# 33/33 [==============================] - 1s 40ms/step - loss: 0.0885 - val_loss: 0.0880
# Epoch 33/80
# 33/33 [==============================] - 1s 40ms/step - loss: 0.0883 - val_loss: 0.0879
# Epoch 34/80
# 33/33 [==============================] - 1s 40ms/step - loss: 0.0883 - val_loss: 0.0879
# Epoch 35/80
# 33/33 [==============================] - 1s 40ms/step - loss: 0.0882 - val_loss: 0.0879
# Epoch 36/80
# 33/33 [==============================] - 1s 40ms/step - loss: 0.0883 - val_loss: 0.0883
# Epoch 37/80
# 33/33 [==============================] - 1s 40ms/step - loss: 0.0882 - val_loss: 0.0885
# Epoch 38/80
# 33/33 [==============================] - 1s 40ms/step - loss: 0.0882 - val_loss: 0.0877
# Epoch 39/80
# 33/33 [==============================] - 1s 40ms/step - loss: 0.0880 - val_loss: 0.0877
# Epoch 40/80
# 33/33 [==============================] - 1s 41ms/step - loss: 0.0880 - val_loss: 0.0880
# Epoch 41/80
# 33/33 [==============================] - 1s 40ms/step - loss: 0.0880 - val_loss: 0.0878
# Epoch 42/80
# 33/33 [==============================] - 1s 40ms/step - loss: 0.0879 - val_loss: 0.0876
# Epoch 43/80
# 33/33 [==============================] - 1s 40ms/step - loss: 0.0879 - val_loss: 0.0875
# Epoch 44/80
# 33/33 [==============================] - 1s 40ms/step - loss: 0.0878 - val_loss: 0.0875
# Epoch 45/80
# 33/33 [==============================] - 1s 40ms/step - loss: 0.0881 - val_loss: 0.0875
# Epoch 46/80
# 33/33 [==============================] - 1s 41ms/step - loss: 0.0880 - val_loss: 0.0882
# Epoch 47/80
# 33/33 [==============================] - 1s 41ms/step - loss: 0.0879 - val_loss: 0.0875
# Epoch 48/80
# 33/33 [==============================] - 1s 41ms/step - loss: 0.0877 - val_loss: 0.0874
# Epoch 49/80
# 33/33 [==============================] - 1s 41ms/step - loss: 0.0879 - val_loss: 0.0877
# Epoch 50/80
# 33/33 [==============================] - 1s 40ms/step - loss: 0.0876 - val_loss: 0.0873
# Epoch 51/80
# 33/33 [==============================] - 1s 41ms/step - loss: 0.0876 - val_loss: 0.0873
# Epoch 52/80
# 33/33 [==============================] - 1s 41ms/step - loss: 0.0878 - val_loss: 0.0873
# Epoch 53/80
# 33/33 [==============================] - 1s 41ms/step - loss: 0.0876 - val_loss: 0.0872
# Epoch 54/80
# 33/33 [==============================] - 1s 41ms/step - loss: 0.0877 - val_loss: 0.0872
# Epoch 55/80
# 33/33 [==============================] - 1s 41ms/step - loss: 0.0877 - val_loss: 0.0874
# Epoch 56/80
# 33/33 [==============================] - 1s 40ms/step - loss: 0.0876 - val_loss: 0.0872
# Epoch 57/80
# 33/33 [==============================] - 1s 40ms/step - loss: 0.0876 - val_loss: 0.0872
# Epoch 58/80
# 33/33 [==============================] - 1s 41ms/step - loss: 0.0875 - val_loss: 0.0871
# Epoch 59/80
# 33/33 [==============================] - 1s 40ms/step - loss: 0.0876 - val_loss: 0.0871
# Epoch 60/80
# 33/33 [==============================] - 1s 40ms/step - loss: 0.0877 - val_loss: 0.0881
# Epoch 61/80
# 33/33 [==============================] - 1s 40ms/step - loss: 0.0879 - val_loss: 0.0871
# Epoch 62/80
# 33/33 [==============================] - 1s 40ms/step - loss: 0.0876 - val_loss: 0.0872
# Epoch 63/80
# 33/33 [==============================] - 1s 41ms/step - loss: 0.0875 - val_loss: 0.0871
# Epoch 64/80
# 33/33 [==============================] - 1s 40ms/step - loss: 0.0875 - val_loss: 0.0878
# Epoch 65/80
# 33/33 [==============================] - 1s 40ms/step - loss: 0.0877 - val_loss: 0.0880
# Epoch 66/80
# 33/33 [==============================] - 1s 41ms/step - loss: 0.0875 - val_loss: 0.0873
# Epoch 67/80
# 33/33 [==============================] - 1s 41ms/step - loss: 0.0874 - val_loss: 0.0870
# Epoch 68/80
# 33/33 [==============================] - 1s 41ms/step - loss: 0.0873 - val_loss: 0.0871
# Epoch 69/80
# 33/33 [==============================] - 1s 41ms/step - loss: 0.0873 - val_loss: 0.0873
# Epoch 70/80
# 33/33 [==============================] - 1s 41ms/step - loss: 0.0874 - val_loss: 0.0873
# Epoch 71/80
# 33/33 [==============================] - 1s 41ms/step - loss: 0.0874 - val_loss: 0.0870
# Epoch 72/80
# 33/33 [==============================] - 1s 41ms/step - loss: 0.0874 - val_loss: 0.0870
# Epoch 73/80
# 33/33 [==============================] - 1s 40ms/step - loss: 0.0873 - val_loss: 0.0870
# Epoch 74/80
# 33/33 [==============================] - 1s 41ms/step - loss: 0.0873 - val_loss: 0.0870
# Epoch 75/80
# 33/33 [==============================] - 1s 41ms/step - loss: 0.0873 - val_loss: 0.0870
# Epoch 76/80
# 33/33 [==============================] - 1s 41ms/step - loss: 0.0872 - val_loss: 0.0870
# Epoch 77/80
# 33/33 [==============================] - 1s 40ms/step - loss: 0.0872 - val_loss: 0.0869
# Epoch 78/80
# 33/33 [==============================] - 1s 41ms/step - loss: 0.0872 - val_loss: 0.0871
# Epoch 79/80
# 33/33 [==============================] - 1s 41ms/step - loss: 0.0872 - val_loss: 0.0868
# Epoch 80/80
# 33/33 [==============================] - 1s 40ms/step - loss: 0.0872 - val_loss: 0.0868

# %%
encoded_imgs = autoencoder.encoder(x_cr_test[:30]).numpy()
decoded_imgs = autoencoder.decoder(encoded_imgs).numpy()

# %%
n = 10
plt.figure(figsize=(20, 4))
for i in range(n):
    # display original
    ax = plt.subplot(2, n, i + 1)
    plt.imshow(x_cr_test[i])
    plt.title("original")
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

    # display reconstruction
    ax = plt.subplot(2, n, i + 1 + n)
    plt.imshow(decoded_imgs[i])
    plt.title("reconstruit")
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
plt.show()

# %%
def extract_label(img_path, train = True):
    filename, _ = os.path.splitext(os.path.basename(img_path))
    subject_id, etc = filename.split('__')
    if train:
        gender, lr, finger, _ = etc.split('_')[:4]
    if finger == 'thumb':
        finger = 0
    elif finger == 'index':
        finger = 1
    elif finger == 'middle':
        finger = 2
    elif finger == 'ring':
        finger = 3
    elif finger == 'little':
        finger = 4
    return finger

def loading_data(path,train, img_size):
    print("loading data from: ",path)
    data = []
    for img in os.listdir(path):
        img_array = cv2.imread(os.path.join(path, img), cv2.IMREAD_GRAYSCALE)
        img_resize = cv2.resize(img_array, (img_size, img_size))
        label = extract_label(os.path.join(path, img),train)
        data.append([label, img_resize])
    return data

def results(model, epoch, batch_size):
    r = model.fit(x_train, y_train, batch_size=batch_size, epochs=epoch, validation_data=(x_test, y_test), verbose=1)
    acc = model.evaluate(x_test, y_test)
    print("test set loss: ", acc[0])
    print("test set accuracy: ", acc[1]*100)
    epoch_range = range(1, epoch+1)
    plt.plot(epoch_range, r.history['accuracy'])
    plt.plot(epoch_range, r.history['val_accuracy'])
    plt.title('Classification Accuracy')
    plt.ylabel('Accuracy')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Val'], loc='lower right')
    plt.show()
    
    # Plot training & validation loss values
    plt.plot(epoch_range,r.history['loss'])
    plt.plot(epoch_range, r.history['val_loss'])
    plt.title('Model loss')
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Val'], loc='lower right')
    plt.show()

src_data = os.path.join(ROOT_DIR,"SOCOFing")
easy_data = loading_data(os.path.join(src_data, os.path.join("Altered","Altered-Easy")), True, 28)
medium_data = loading_data(os.path.join(src_data, os.path.join("Altered","Altered-Medium")), True, 28)
hard_data = loading_data(os.path.join(src_data, os.path.join("Altered","Altered-Hard")), True, 28)
data = np.concatenate([easy_data, medium_data, hard_data], axis=0)
import random

random.shuffle(data)

img, labels = [], []
for label, feature in data:
    labels.append(label)
    img.append(feature)
img = np.array(img).reshape(-1, 28, 28, 1)
labels = tf.keras.utils.to_categorical(labels)
x_train, x_test, y_train, y_test = train_test_split(img, labels, test_size=0.2, random_state=0)

print("x_train dimensions: ", x_train.shape)
print("x_test dimensions: ", x_test.shape)
print("y_train dimensions: ", y_train.shape)
print("y_test dimensions: ", y_test.shape)

x_train, x_val, y_train, y_val = train_test_split(x_train, y_train, test_size=0.05, random_state=0)

datagen = ImageDataGenerator(
            rotation_range=15,
            width_shift_range=0.1,
            height_shift_range=0.1,
            horizontal_flip=True)

def normalize(data):
    data = data.astype("float32")
    data = data/255
    return data

print("x_train dimensions: ", x_train.shape)
print("x_val dimensions: ", x_val.shape)
print("y_train dimensions: ", y_train.shape)
print("y_val dimensions: ", y_val.shape)


mirrored_strategy = tf.distribute.MirroredStrategy(devices=["/gpu:0"],cross_device_ops=tf.distribute.HierarchicalCopyAllReduce())

tf.keras.backend.clear_session()
weight_decay = 1e-4
with mirrored_strategy.scope():
    model_f = Sequential([
            Conv2D(32, (3, 3), activation = 'relu', padding = 'same', input_shape = (28,28,1)),
              Conv2D(32, (3, 3), activation = 'relu', padding = 'same'),
              MaxPooling2D((2, 2)),
              Conv2D(64, (3, 3), activation = 'relu', padding = 'same'),
              Conv2D(64, (3, 3), activation = 'relu', padding = 'same'),
              MaxPooling2D((2, 2)),
              Conv2D(128, (3, 3), activation = 'relu', padding = 'same'),
              Conv2D(128, (3, 3), activation = 'relu', padding = 'same'),
              MaxPooling2D((2, 2)),
              Flatten(),
              Dense(128, activation = 'relu'),
              Dense(5, activation = 'softmax')
    ])
    model_f.summary()
    opt = tf.keras.optimizers.Adam(learning_rate=0.0001)
    model_f.compile(optimizer=opt, loss='binary_crossentropy', metrics=['accuracy'])
    results(model_f, 60, 128)

# test in Real data

real_data = loading_data(os.path.join(src_data, os.path.join("Real")), True, 28)
img, labels = [], []
for label, feature in real_data:
    labels.append(label)
    img.append(feature)
img = np.array(img).reshape(-1, 28, 28, 1)
# Out:
# loading data from:  C:/Users/anass/my_ds/fingerprint_class\SOCOFing\Altered\Altered-Easy
# loading data from:  C:/Users/anass/my_ds/fingerprint_class\SOCOFing\Altered\Altered-Medium
# loading data from:  C:/Users/anass/my_ds/fingerprint_class\SOCOFing\Altered\Altered-Hard
# <__array_function__ internals>:5: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# x_train dimensions:  (39416, 28, 28, 1)
# x_test dimensions:  (9854, 28, 28, 1)
# y_train dimensions:  (39416, 5)
# y_test dimensions:  (9854, 5)
# x_train dimensions:  (37445, 28, 28, 1)
# x_val dimensions:  (1971, 28, 28, 1)
# y_train dimensions:  (37445, 5)
# y_val dimensions:  (1971, 5)
# WARNING:tensorflow:Collective ops is not configured at program startup. Some performance features may not be enabled.
# INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0',)
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 28, 28, 32)        320
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 28, 28, 32)        9248
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 14, 14, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 14, 14, 64)        18496
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 14, 14, 64)        36928
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 7, 7, 64)          0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 7, 7, 128)         73856
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 7, 7, 128)         147584
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 3, 3, 128)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 1152)              0
# _________________________________________________________________
# dense (Dense)                (None, 128)               147584
# _________________________________________________________________
# dense_1 (Dense)              (None, 5)                 645
# =================================================================
# Total params: 434,661
# Trainable params: 434,661
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/60
# 293/293 [==============================] - 21s 63ms/step - loss: 0.4259 - accuracy: 0.4741 - val_loss: 0.3739 - val_accuracy: 0.5553
# Epoch 2/60
# 293/293 [==============================] - 17s 58ms/step - loss: 0.3419 - accuracy: 0.6097 - val_loss: 0.3478 - val_accuracy: 0.5828
# Epoch 3/60
# 293/293 [==============================] - 17s 57ms/step - loss: 0.2926 - accuracy: 0.6942 - val_loss: 0.2803 - val_accuracy: 0.7194
# Epoch 4/60
# 293/293 [==============================] - 17s 57ms/step - loss: 0.2428 - accuracy: 0.7711 - val_loss: 0.2357 - val_accuracy: 0.7775
# Epoch 5/60
# 293/293 [==============================] - 17s 57ms/step - loss: 0.1978 - accuracy: 0.8332 - val_loss: 0.2146 - val_accuracy: 0.7989
# Epoch 6/60
# 293/293 [==============================] - 17s 57ms/step - loss: 0.1608 - accuracy: 0.8768 - val_loss: 0.2147 - val_accuracy: 0.8031
# Epoch 7/60
# 293/293 [==============================] - 17s 57ms/step - loss: 0.1254 - accuracy: 0.9159 - val_loss: 0.1451 - val_accuracy: 0.8906
# Epoch 8/60
# 293/293 [==============================] - 17s 57ms/step - loss: 0.0970 - accuracy: 0.9427 - val_loss: 0.1257 - val_accuracy: 0.9069
# Epoch 9/60
# 293/293 [==============================] - 17s 57ms/step - loss: 0.0775 - accuracy: 0.9575 - val_loss: 0.1098 - val_accuracy: 0.9196
# Epoch 10/60
# 293/293 [==============================] - 17s 57ms/step - loss: 0.0591 - accuracy: 0.9716 - val_loss: 0.0915 - val_accuracy: 0.9352
# Epoch 11/60
# 293/293 [==============================] - 17s 57ms/step - loss: 0.0453 - accuracy: 0.9815 - val_loss: 0.0981 - val_accuracy: 0.9318
# Epoch 12/60
# 293/293 [==============================] - 17s 57ms/step - loss: 0.0356 - accuracy: 0.9870 - val_loss: 0.0866 - val_accuracy: 0.9383
# Epoch 13/60
# 293/293 [==============================] - 17s 57ms/step - loss: 0.0258 - accuracy: 0.9927 - val_loss: 0.0717 - val_accuracy: 0.9518
# Epoch 14/60
# 293/293 [==============================] - 17s 57ms/step - loss: 0.0197 - accuracy: 0.9954 - val_loss: 0.0722 - val_accuracy: 0.9535
# Epoch 15/60
# 293/293 [==============================] - 17s 57ms/step - loss: 0.0145 - accuracy: 0.9975 - val_loss: 0.0648 - val_accuracy: 0.9575
# Epoch 16/60
# 293/293 [==============================] - 17s 57ms/step - loss: 0.0123 - accuracy: 0.9984 - val_loss: 0.0657 - val_accuracy: 0.9567
# Epoch 17/60
# 293/293 [==============================] - 17s 57ms/step - loss: 0.0088 - accuracy: 0.9992 - val_loss: 0.0699 - val_accuracy: 0.9561
# Epoch 18/60
# 293/293 [==============================] - 17s 57ms/step - loss: 0.0073 - accuracy: 0.9994 - val_loss: 0.0614 - val_accuracy: 0.9607
# Epoch 19/60
# 293/293 [==============================] - 17s 57ms/step - loss: 0.0043 - accuracy: 0.9999 - val_loss: 0.0601 - val_accuracy: 0.9627
# Epoch 20/60
# 293/293 [==============================] - 17s 57ms/step - loss: 0.0050 - accuracy: 0.9995 - val_loss: 0.0839 - val_accuracy: 0.9506
# Epoch 21/60
# 293/293 [==============================] - 17s 57ms/step - loss: 0.0078 - accuracy: 0.9992 - val_loss: 0.0713 - val_accuracy: 0.9570
# Epoch 22/60
# 293/293 [==============================] - 17s 57ms/step - loss: 0.0195 - accuracy: 0.9924 - val_loss: 0.0597 - val_accuracy: 0.9631
# Epoch 23/60
# 293/293 [==============================] - 17s 57ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.0576 - val_accuracy: 0.9644
# Epoch 24/60
# 293/293 [==============================] - 17s 57ms/step - loss: 9.1330e-04 - accuracy: 1.0000 - val_loss: 0.0605 - val_accuracy: 0.9648
# Epoch 25/60
# 293/293 [==============================] - 17s 57ms/step - loss: 6.7753e-04 - accuracy: 1.0000 - val_loss: 0.0615 - val_accuracy: 0.9652
# Epoch 26/60
# 293/293 [==============================] - 17s 57ms/step - loss: 5.4452e-04 - accuracy: 1.0000 - val_loss: 0.0616 - val_accuracy: 0.9654
# Epoch 27/60
# 293/293 [==============================] - 17s 57ms/step - loss: 4.6028e-04 - accuracy: 1.0000 - val_loss: 0.0642 - val_accuracy: 0.9648
# Epoch 28/60
# 293/293 [==============================] - 17s 57ms/step - loss: 3.9367e-04 - accuracy: 1.0000 - val_loss: 0.0630 - val_accuracy: 0.9653
# Epoch 29/60
# 293/293 [==============================] - 17s 57ms/step - loss: 3.3018e-04 - accuracy: 1.0000 - val_loss: 0.0645 - val_accuracy: 0.9650
# Epoch 30/60
# 293/293 [==============================] - 17s 57ms/step - loss: 2.8065e-04 - accuracy: 1.0000 - val_loss: 0.0645 - val_accuracy: 0.9652
# Epoch 31/60
# 293/293 [==============================] - 17s 57ms/step - loss: 2.4520e-04 - accuracy: 1.0000 - val_loss: 0.0660 - val_accuracy: 0.9647
# Epoch 32/60
# 293/293 [==============================] - 17s 57ms/step - loss: 2.0555e-04 - accuracy: 1.0000 - val_loss: 0.0667 - val_accuracy: 0.9654
# Epoch 33/60
# 293/293 [==============================] - 17s 57ms/step - loss: 1.7543e-04 - accuracy: 1.0000 - val_loss: 0.0671 - val_accuracy: 0.9651
# Epoch 34/60
# 293/293 [==============================] - 17s 57ms/step - loss: 1.5277e-04 - accuracy: 1.0000 - val_loss: 0.0686 - val_accuracy: 0.9656
# Epoch 35/60
# 293/293 [==============================] - 17s 57ms/step - loss: 1.2813e-04 - accuracy: 1.0000 - val_loss: 0.0688 - val_accuracy: 0.9657
# Epoch 36/60
# 293/293 [==============================] - 17s 57ms/step - loss: 1.0857e-04 - accuracy: 1.0000 - val_loss: 0.0701 - val_accuracy: 0.9665
# Epoch 37/60
# 293/293 [==============================] - 17s 57ms/step - loss: 9.4133e-05 - accuracy: 1.0000 - val_loss: 0.0700 - val_accuracy: 0.9655
# Epoch 38/60
# 293/293 [==============================] - 18s 60ms/step - loss: 7.9417e-05 - accuracy: 1.0000 - val_loss: 0.0717 - val_accuracy: 0.9660
# Epoch 39/60
# 293/293 [==============================] - 17s 59ms/step - loss: 6.7363e-05 - accuracy: 1.0000 - val_loss: 0.0734 - val_accuracy: 0.9655
# Epoch 40/60
# 293/293 [==============================] - 17s 59ms/step - loss: 5.6114e-05 - accuracy: 1.0000 - val_loss: 0.0737 - val_accuracy: 0.9663
# Epoch 41/60
# 293/293 [==============================] - 18s 61ms/step - loss: 4.9125e-05 - accuracy: 1.0000 - val_loss: 0.0740 - val_accuracy: 0.9663
# Epoch 42/60
# 293/293 [==============================] - 17s 57ms/step - loss: 0.0357 - accuracy: 0.9860 - val_loss: 0.3176 - val_accuracy: 0.7272
# Epoch 43/60
# 293/293 [==============================] - 17s 57ms/step - loss: 0.0391 - accuracy: 0.9754 - val_loss: 0.0631 - val_accuracy: 0.9656
# Epoch 44/60
# 293/293 [==============================] - 17s 57ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.0637 - val_accuracy: 0.9656
# Epoch 45/60
# 293/293 [==============================] - 17s 57ms/step - loss: 4.0885e-04 - accuracy: 1.0000 - val_loss: 0.0644 - val_accuracy: 0.9669
# Epoch 46/60
# 293/293 [==============================] - 17s 57ms/step - loss: 2.8162e-04 - accuracy: 1.0000 - val_loss: 0.0657 - val_accuracy: 0.9670
# Epoch 47/60
# 293/293 [==============================] - 17s 57ms/step - loss: 2.1675e-04 - accuracy: 1.0000 - val_loss: 0.0669 - val_accuracy: 0.9658
# Epoch 48/60
# 293/293 [==============================] - 17s 57ms/step - loss: 1.7577e-04 - accuracy: 1.0000 - val_loss: 0.0680 - val_accuracy: 0.9662
# Epoch 49/60
# 293/293 [==============================] - 17s 57ms/step - loss: 1.4562e-04 - accuracy: 1.0000 - val_loss: 0.0684 - val_accuracy: 0.9666
# Epoch 50/60
# 293/293 [==============================] - 17s 57ms/step - loss: 1.2307e-04 - accuracy: 1.0000 - val_loss: 0.0687 - val_accuracy: 0.9667
# Epoch 51/60
# 293/293 [==============================] - 17s 57ms/step - loss: 1.0558e-04 - accuracy: 1.0000 - val_loss: 0.0703 - val_accuracy: 0.9665
# Epoch 52/60
# 293/293 [==============================] - 17s 57ms/step - loss: 9.1523e-05 - accuracy: 1.0000 - val_loss: 0.0704 - val_accuracy: 0.9663
# Epoch 53/60
# 293/293 [==============================] - 17s 57ms/step - loss: 7.9767e-05 - accuracy: 1.0000 - val_loss: 0.0710 - val_accuracy: 0.9665
# Epoch 54/60
# 293/293 [==============================] - 17s 57ms/step - loss: 6.9884e-05 - accuracy: 1.0000 - val_loss: 0.0716 - val_accuracy: 0.9669
# Epoch 55/60
# 293/293 [==============================] - 17s 57ms/step - loss: 6.1535e-05 - accuracy: 1.0000 - val_loss: 0.0728 - val_accuracy: 0.9667
# Epoch 56/60
# 293/293 [==============================] - 17s 57ms/step - loss: 5.4606e-05 - accuracy: 1.0000 - val_loss: 0.0726 - val_accuracy: 0.9667
# Epoch 57/60
# 293/293 [==============================] - 17s 59ms/step - loss: 4.8682e-05 - accuracy: 1.0000 - val_loss: 0.0735 - val_accuracy: 0.9665
# Epoch 58/60
# 293/293 [==============================] - 18s 62ms/step - loss: 4.3388e-05 - accuracy: 1.0000 - val_loss: 0.0748 - val_accuracy: 0.9655
# Epoch 59/60
# 293/293 [==============================] - 18s 60ms/step - loss: 3.8526e-05 - accuracy: 1.0000 - val_loss: 0.0744 - val_accuracy: 0.9663
# Epoch 60/60
# 293/293 [==============================] - 17s 58ms/step - loss: 3.4266e-05 - accuracy: 1.0000 - val_loss: 0.0752 - val_accuracy: 0.9661
# 308/308 [==============================] - 2s 8ms/step - loss: 0.0752 - accuracy: 0.9661
# test set loss:  0.07521703839302063
# test set accuracy:  96.61051630973816
# loading data from:  C:/Users/anass/my_ds/fingerprint_class\SOCOFing\Real
# Confusion Matrix
# [[1194    2    1    1    2]
#  [   1 1182    3    6    8]
#  [   1    8 1183    7    1]
#  [   4   12   17 1165    2]
#  [   2   10    7   11 1170]]
# Classification Report
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-110-5f6ac8f53811> in <module>
#     131 print('Classification Report')
#     132 target_names = ['Male', 'Female']
# --> 133 print(classification_report(labels, y_pred, target_names=target_names))
#
# c:\users\anass\my_ds\fingerprint_class\vfinger\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# c:\users\anass\my_ds\fingerprint_class\vfinger\lib\site-packages\sklearn\metrics\_classification.py in classification_report(y_true, y_pred, labels, target_names, sample_weight, digits, output_dict, zero_division)
#    1989             )
#    1990         else:
# -> 1991             raise ValueError(
#    1992                 "Number of classes, {0}, does not match size of "
#    1993                 "target_names, {1}. Try specifying the labels "
#
# ValueError: Number of classes, 5, does not match size of target_names, 2. Try specifying the labels parameter

# %%
model_f.save('model2.h5')

# %%
# confusion matrix
from sklearn.metrics import classification_report, confusion_matrix
Y_pred = model_f.predict(img)
y_pred = np.argmax(Y_pred, axis=1)
print('Confusion Matrix')
print(confusion_matrix(labels, y_pred))
print('Classification Report')
target_names = ['Thumb', 'Index', 'Middle', 'Ring', 'Little']
print(classification_report(labels, y_pred, target_names=target_names))
# Out:
# Confusion Matrix
# [[1194    2    1    1    2]
#  [   1 1182    3    6    8]
#  [   1    8 1183    7    1]
#  [   4   12   17 1165    2]
#  [   2   10    7   11 1170]]
# Classification Report
#               precision    recall  f1-score   support
#
#        Thumb       0.99      0.99      0.99      1200
#        Index       0.97      0.98      0.98      1200
#       Middle       0.98      0.99      0.98      1200
#         Ring       0.98      0.97      0.97      1200
#       Little       0.99      0.97      0.98      1200
#
#     accuracy                           0.98      6000
#    macro avg       0.98      0.98      0.98      6000
# weighted avg       0.98      0.98      0.98      6000
